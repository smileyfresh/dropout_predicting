# %%
import pandas as pd

# %% [markdown]
# # Demographic Data

# %%
demographics_raw = pd.read_csv('raw/Student_Demographics_Raw.csv')

# %%
demographics_raw
# Out:
#          sid  school_year  male race_ethnicity  birth_date  \
# 0          1         2004     1              B     10869.0
# 1          1         2005     1              H     10869.0
# 2          1         2006     1              H     10869.0
# 3          1         2007     1              H     10869.0
# 4          2         2006     0              W     11948.0
# ...      ...          ...   ...            ...         ...
# 87529  21803         2004     0              A     11959.0
# 87530  21803         2005     0              A     11959.0
# 87531  21803         2006     0              A     11959.0
# 87532  21803         2007     0              A     11959.0
# 87533  21803         2008     0              A     11959.0
#
#        first_9th_school_year_reported  hs_diploma       hs_diploma_type  \
# 0                              2004.0           0                   NaN
# 1                              2004.0           0                   NaN
# 2                              2004.0           0                   NaN
# 3                              2004.0           0                   NaN
# 4                                 NaN           1      Standard Diploma
# ...                               ...         ...                   ...
# 87529                          2005.0           1  College Prep Diploma
# 87530                          2005.0           1  College Prep Diploma
# 87531                          2005.0           1  College Prep Diploma
# 87532                          2005.0           1  College Prep Diploma
# 87533                          2005.0           1  College Prep Diploma
#
#       hs_diploma_date
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4           05jun2008
# ...               ...
# 87529       14may2008
# 87530       14may2008
# 87531       14may2008
# 87532       14may2008
# 87533       14may2008
#
# [87534 rows x 9 columns]

# %%
demographics_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87534 entries, 0 to 87533
# Data columns (total 9 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   sid                             87534 non-null  int64
#  1   school_year                     87534 non-null  int64
#  2   male                            87534 non-null  int64
#  3   race_ethnicity                  86405 non-null  object
#  4   birth_date                      87487 non-null  float64
#  5   first_9th_school_year_reported  82805 non-null  float64
#  6   hs_diploma                      87534 non-null  int64
#  7   hs_diploma_type                 24701 non-null  object
#  8   hs_diploma_date                 24428 non-null  object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 6.0+ MB

# %% [markdown]
# ### Let's define these features (https://hwpi.harvard.edu/files/sdp/files/step_1_stata_identify_data_specification_guide.pdf)
#
#     - SID - a student's unique identification number
#     - school year - academic school year(defined by spring semester) that the data was collected (note students may have updated attributes -- i.e. changed values  of the attributes -- each school year
#     - male - whether or not a student is male or female -- 0 being female, 1 being male
#     - birth_date
#     - first_9th_school_year_reported - when student entered high school(accounts for students who may repeat grades; will help later in calculating length of time in hs/whether or not student met 4-year graduation rate)
#     - hs_diploma - whether or not student received diploma
#     - hs_diploma_type

# %%
demographics_raw.shape
# Out:
# (87534, 9)

# %%
demographics_raw.describe()
# Out:
#                 sid   school_year          male    birth_date  \
# count  87534.000000  87534.000000  87534.000000  87487.000000
# mean   10909.683986   2006.471554      0.501200  12068.978031
# std     6296.298547      1.599801      0.500001    556.849235
# min        1.000000   2004.000000      0.000000  10869.000000
# 25%     5457.000000   2005.000000      0.000000  11700.000000
# 50%    10903.500000   2006.000000      1.000000  12077.000000
# 75%    16378.000000   2008.000000      1.000000  12447.000000
# max    21803.000000   2009.000000      1.000000  13148.000000
#
#        first_9th_school_year_reported    hs_diploma
# count                    82805.000000  87534.000000
# mean                      2006.541211      0.279069
# std                          1.131027      0.448544
# min                       1999.000000      0.000000
# 25%                       2006.000000      0.000000
# 50%                       2007.000000      0.000000
# 75%                       2008.000000      1.000000
# max                       2010.000000      1.000000

# %%
len(demographics_raw['sid'].unique())
# Out:
# 21803

# %%
demographics_raw.groupby('sid').count()
# Out:
#        school_year  male  race_ethnicity  birth_date  \
# sid
# 1                4     4               4           4
# 2                2     2               2           2
# 3                3     3               3           3
# 4                3     3               3           3
# 5                1     1               1           0
# ...            ...   ...             ...         ...
# 21799            4     4               4           4
# 21800            6     6               6           6
# 21801            2     2               2           2
# 21802            6     6               6           6
# 21803            5     5               5           5
#
#        first_9th_school_year_reported  hs_diploma  hs_diploma_type  \
# sid
# 1                                   4           4                0
# 2                                   0           2                2
# 3                                   3           3                0
# 4                                   3           3                3
# 5                                   0           1                0
# ...                               ...         ...              ...
# 21799                               4           4                0
# 21800                               6           6                6
# 21801                               2           2                0
# 21802                               6           6                0
# 21803                               5           5                5
#
#        hs_diploma_date
# sid
# 1                    0
# 2                    2
# 3                    0
# 4                    3
# 5                    0
# ...                ...
# 21799                0
# 21800                6
# 21801                0
# 21802                0
# 21803                5
#
# [21803 rows x 8 columns]

# %% [markdown]
# ### Note that the shape of the raw data is 87534, but there are only 21803 unique student ids. The student ids should be unique identifiers. We need to clean the data so that there is only one row for each student.
#
# But in order to do this we need to figure out student's true gender, race/ethnicity, and birthdate

# %%
demographics_raw.groupby('sid').groups
# Out:
# {1: [0, 1, 2, 3], 2: [4, 5], 3: [6, 7, 8], 4: [9, 10, 11], 5: [12], 6: [13, 14, 15], 7: [16, 17, 18, 19, 20], 8: [21, 22, 23, 24], 9: [25, 26, 27, 28], 10: [29, 30, 31, 32, 33], 11: [34], 12: [35, 36], 13: [37, 38], 14: [39, 40, 41, 42, 43, 44], 15: [45, 46], 16: [47, 48], 17: [49, 50], 18: [51, 52, 53, 54, 55], 19: [56, 57], 20: [58, 59], 21: [60, 61, 62, 63, 64, 65], 22: [66, 67, 68], 23: [69, 70, 71, 72, 73, 74], 24: [75, 76, 77, 78, 79, 80], 25: [81, 82, 83, 84, 85], 26: [86, 87, 88, 89], 27: [90, 91, 92, 93, 94, 95], 28: [96], 29: [97, 98, 99], 30: [100, 101, 102, 103], 31: [104, 105, 106], 32: [107, 108, 109, 110], 33: [111, 112], 34: [113, 114, 115, 116, 117, 118], 35: [119, 120, 121, 122, 123], 36: [124, 125, 126, 127, 128, 129], 37: [130, 131, 132], 38: [133, 134, 135, 136, 137], 39: [138, 139], 40: [140, 141, 142, 143, 144, 145], 41: [146, 147, 148, 149, 150], 42: [151, 152, 153, 154, 155], 43: [156, 157, 158, 159, 160, 161], 44: [162, 163, 164, 165, 166, 167], 45: [168, 169, 170, 171, 172], 46: [173, 174, 175, 176, 177], 47: [178, 179, 180, 181, 182, 183], 48: [184, 185, 186], 49: [187, 188, 189, 190, 191], 50: [192, 193, 194, 195], 51: [196, 197, 198, 199, 200], 52: [201, 202, 203, 204, 205, 206], 53: [207, 208, 209], 54: [210, 211, 212, 213, 214, 215], 55: [216], 56: [217, 218, 219], 57: [220, 221, 222, 223, 224], 58: [225, 226, 227, 228, 229, 230], 59: [231, 232], 60: [233, 234], 61: [235, 236, 237, 238, 239], 62: [240, 241, 242, 243], 63: [244, 245, 246, 247], 64: [248, 249, 250, 251, 252, 253], 65: [254, 255, 256, 257, 258], 66: [259, 260, 261, 262, 263], 67: [264, 265, 266, 267, 268, 269], 68: [270], 69: [271, 272, 273, 274, 275], 70: [276], 71: [277, 278], 72: [279, 280, 281, 282], 73: [283, 284, 285, 286, 287], 74: [288, 289, 290, 291, 292], 75: [293, 294, 295, 296, 297], 76: [298, 299, 300, 301, 302, 303], 77: [304, 305, 306, 307, 308, 309], 78: [310, 311, 312], 79: [313, 314, 315, 316, 317, 318], 80: [319, 320, 321, 322], 81: [323, 324], 82: [325, 326, 327, 328, 329, 330], 83: [331], 84: [332, 333, 334], 85: [335, 336, 337, 338, 339], 86: [340, 341, 342, 343], 87: [344, 345, 346, 347, 348, 349], 88: [350, 351, 352, 353], 89: [354, 355, 356, 357, 358, 359], 90: [360, 361, 362], 91: [363, 364, 365, 366], 92: [367, 368, 369, 370], 93: [371, 372, 373, 374], 94: [375, 376, 377], 95: [378, 379, 380, 381, 382], 96: [383, 384, 385, 386, 387], 97: [388, 389, 390], 98: [391], 99: [392, 393, 394, 395], 100: [396, 397, 398, 399, 400, 401], ...}

# %% [markdown]
# So the nice news is that the data is sorted by student id, so they are informally grouped together

# %%
demographics_raw.head(30)
# Out:
#     sid  school_year  male race_ethnicity  birth_date  \
# 0     1         2004     1              B     10869.0
# 1     1         2005     1              H     10869.0
# 2     1         2006     1              H     10869.0
# 3     1         2007     1              H     10869.0
# 4     2         2006     0              W     11948.0
# 5     2         2007     0              B     11948.0
# 6     3         2006     1              H     11724.0
# 7     3         2006     1              B     11724.0
# 8     3         2007     1              B     11724.0
# 9     4         2005     0              B     12717.0
# 10    4         2006     0              B     12717.0
# 11    4         2007     0              B     12717.0
# 12    5         2007     1              B         NaN
# 13    6         2007     1              H     12055.0
# 14    6         2008     1              H     12055.0
# 15    6         2009     1              H     12055.0
# 16    7         2004     1              H     10960.0
# 17    7         2005     1              H     10960.0
# 18    7         2006     1              H     10960.0
# 19    7         2007     0              H     10960.0
# 20    7         2008     1              H     10960.0
# 21    8         2004     1              H     11691.0
# 22    8         2005     1              H     11691.0
# 23    8         2006     1              H     11691.0
# 24    8         2007     1              H     11691.0
# 25    9         2004     1              H     11326.0
# 26    9         2005     1              H     11326.0
# 27    9         2006     1              H     11326.0
# 28    9         2007     1              H     11326.0
# 29   10         2004     1              W     10962.0
#
#     first_9th_school_year_reported  hs_diploma       hs_diploma_type  \
# 0                           2004.0           0                   NaN
# 1                           2004.0           0                   NaN
# 2                           2004.0           0                   NaN
# 3                           2004.0           0                   NaN
# 4                              NaN           1      Standard Diploma
# 5                              NaN           1  College Prep Diploma
# 6                           2007.0           0                   NaN
# 7                           2007.0           0                   NaN
# 8                           2007.0           0                   NaN
# 9                           2007.0           1      Standard Diploma
# 10                          2007.0           1      Standard Diploma
# 11                          2007.0           1      Standard Diploma
# 12                             NaN           0                   NaN
# 13                          2008.0           0                   NaN
# 14                          2008.0           0                   NaN
# 15                          2008.0           0                   NaN
# 16                          2005.0           1      Standard Diploma
# 17                          2005.0           1      Standard Diploma
# 18                          2005.0           1      Standard Diploma
# 19                          2005.0           1      Standard Diploma
# 20                          2005.0           1      Standard Diploma
# 21                          2007.0           0                   NaN
# 22                          2007.0           0                   NaN
# 23                          2007.0           0                   NaN
# 24                          2007.0           0                   NaN
# 25                          2006.0           0                   NaN
# 26                          2006.0           0                   NaN
# 27                          2006.0           0                   NaN
# 28                          2007.0           0                   NaN
# 29                          2005.0           1      Standard Diploma
#
#    hs_diploma_date
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4        05jun2008
# 5        24may2009
# 6              NaN
# 7              NaN
# 8              NaN
# 9        04jun2009
# 10       04jun2009
# 11       04jun2009
# 12             NaN
# 13             NaN
# 14             NaN
# 15             NaN
# 16       14may2008
# 17       14may2008
# 18       14may2008
# 19       14may2008
# 20       14may2008
# 21             NaN
# 22             NaN
# 23             NaN
# 24             NaN
# 25             NaN
# 26             NaN
# 27             NaN
# 28             NaN
# 29       14may2008

# %% [markdown]
# Looking at the list of the first 30 entries, we see the first time things look weird in regard to gender is with student is 7

# %%
one_student = demographics_raw[demographics_raw['sid'] == 7]
one_student
# Out:
#     sid  school_year  male race_ethnicity  birth_date  \
# 16    7         2004     1              H     10960.0
# 17    7         2005     1              H     10960.0
# 18    7         2006     1              H     10960.0
# 19    7         2007     0              H     10960.0
# 20    7         2008     1              H     10960.0
#
#     first_9th_school_year_reported  hs_diploma   hs_diploma_type  \
# 16                          2005.0           1  Standard Diploma
# 17                          2005.0           1  Standard Diploma
# 18                          2005.0           1  Standard Diploma
# 19                          2005.0           1  Standard Diploma
# 20                          2005.0           1  Standard Diploma
#
#    hs_diploma_date
# 16       14may2008
# 17       14may2008
# 18       14may2008
# 19       14may2008
# 20       14may2008

# %% [markdown]
# So in a scenario like this, we need to figure out how to address it...in this case it looks like the female mark may have been a misentry. So how would we find this --> use the mode! Find the mode for each student's male value, if the row['male'] does not equal the mode, update it to the mode.

# %%
mode = one_student['male'].mode().to_numpy()

# %%
mode
# Out:
# array([1])

# %%
one_student['male'][:] = mode[0]
one_student
# Out:
# /Users/kiara/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#     sid  school_year  male race_ethnicity  birth_date  \
# 16    7         2004     1              H     10960.0
# 17    7         2005     1              H     10960.0
# 18    7         2006     1              H     10960.0
# 19    7         2007     1              H     10960.0
# 20    7         2008     1              H     10960.0
#
#     first_9th_school_year_reported  hs_diploma   hs_diploma_type  \
# 16                          2005.0           1  Standard Diploma
# 17                          2005.0           1  Standard Diploma
# 18                          2005.0           1  Standard Diploma
# 19                          2005.0           1  Standard Diploma
# 20                          2005.0           1  Standard Diploma
#
#    hs_diploma_date
# 16       14may2008
# 17       14may2008
# 18       14may2008
# 19       14may2008
# 20       14may2008

# %%
#get a list of modes by student id
male_modes = demographics_raw.groupby('sid', as_index=False)['male']

# %%
male_modes.head()
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        0
#         ..
# 87529    0
# 87530    0
# 87531    0
# 87532    0
# 87533    0
# Name: male, Length: 82963, dtype: int64

# %%
demographics_raw.head(100)
# Out:
#     sid  school_year  male race_ethnicity  birth_date  \
# 0     1         2004     1              B     10869.0
# 1     1         2005     1              H     10869.0
# 2     1         2006     1              H     10869.0
# 3     1         2007     1              H     10869.0
# 4     2         2006     0              W     11948.0
# ..  ...          ...   ...            ...         ...
# 95   27         2009     1              H     11701.0
# 96   28         2009     1              B     11702.0
# 97   29         2004     1              W     10972.0
# 98   29         2005     1              W     10972.0
# 99   29         2006     1              W     10972.0
#
#     first_9th_school_year_reported  hs_diploma   hs_diploma_type  \
# 0                           2004.0           0               NaN
# 1                           2004.0           0               NaN
# 2                           2004.0           0               NaN
# 3                           2004.0           0               NaN
# 4                              NaN           1  Standard Diploma
# ..                             ...         ...               ...
# 95                          2007.0           0               NaN
# 96                             NaN           0               NaN
# 97                          2005.0           0               NaN
# 98                          2005.0           0               NaN
# 99                          2005.0           0               NaN
#
#    hs_diploma_date
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4        05jun2008
# ..             ...
# 95             NaN
# 96             NaN
# 97             NaN
# 98             NaN
# 99             NaN
#
# [100 rows x 9 columns]

# %%
#the question is are there any where the mode
